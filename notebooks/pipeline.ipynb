# %% [markdown]
# # **Adult Census Income Prediction**

# %% [markdown]
# ## **Import Library & Setup Path**

# %%
import os
import sys

# Menambahkan root folder
sys.path.append("..")

# %% [markdown]
# ## **Menjalankan Pipeline**

# %%
# !python ../pipeline.py
# Out:
# /workspaces/adult-census-income/venv/lib/python3.10/site-packages/google/auth/transport/grpc.py:44: FutureWarning: grpcio < 1.83.0 does not support Post-Quantum Cryptography (PQC). Support for non-PQC environments is deprecated. In October 2026, google-auth will raise its minimum requirements to enforce grpcio >= 1.83.0. For more details on Google Cloud's post-quantum security migration, visit: https://cloud.google.com/security/resources/post-quantum-cryptography
#   warnings.warn(
# 2026-09-10 09:14:25.935821: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-09-10 09:14:26.559986: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-09-10 09:14:26.561225: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-10 09:14:28.422971: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying tuner.py -> build/lib
# copying transform.py -> build/lib
# copying trainer.py -> build/lib
# /workspaces/adult-census-income/venv/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# installing to /tmp/tmpusykqxy5
# running install
# running install_lib
# copying build/lib/tuner.py -> /tmp/tmpusykqxy5
# copying build/lib/trainer.py -> /tmp/tmpusykqxy5
# copying build/lib/transform.py -> /tmp/tmpusykqxy5
# running install_egg_info
# running egg_info
# creating tfx_user_code_Transform.egg-info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmpusykqxy5/tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3.10.egg-info
# running install_scripts
# creating /tmp/tmpusykqxy5/tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/WHEEL
# creating '/tmp/tmprq5p3t3w/tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3-none-any.whl' and adding '/tmp/tmpusykqxy5' to it
# adding 'trainer.py'
# adding 'transform.py'
# adding 'tuner.py'
# adding 'tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/RECORD'
# removing /tmp/tmpusykqxy5
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying tuner.py -> build/lib
# copying transform.py -> build/lib
# copying trainer.py -> build/lib
# /workspaces/adult-census-income/venv/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# installing to /tmp/tmpebyp4zhg
# running install
# running install_lib
# copying build/lib/tuner.py -> /tmp/tmpebyp4zhg
# copying build/lib/trainer.py -> /tmp/tmpebyp4zhg
# copying build/lib/transform.py -> /tmp/tmpebyp4zhg
# running install_egg_info
# running egg_info
# creating tfx_user_code_Tuner.egg-info
# writing tfx_user_code_Tuner.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Tuner.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Tuner.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Tuner.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Tuner.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Tuner.egg-info/SOURCES.txt'
# Copying tfx_user_code_Tuner.egg-info to /tmp/tmpebyp4zhg/tfx_user_code_Tuner-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3.10.egg-info
# running install_scripts
# creating /tmp/tmpebyp4zhg/tfx_user_code_Tuner-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/WHEEL
# creating '/tmp/tmp29yrbbun/tfx_user_code_Tuner-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3-none-any.whl' and adding '/tmp/tmpebyp4zhg' to it
# adding 'trainer.py'
# adding 'transform.py'
# adding 'tuner.py'
# adding 'tfx_user_code_Tuner-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/METADATA'
# adding 'tfx_user_code_Tuner-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/WHEEL'
# adding 'tfx_user_code_Tuner-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/top_level.txt'
# adding 'tfx_user_code_Tuner-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/RECORD'
# removing /tmp/tmpebyp4zhg
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying tuner.py -> build/lib
# copying transform.py -> build/lib
# copying trainer.py -> build/lib
# /workspaces/adult-census-income/venv/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# installing to /tmp/tmpkiq0c0qv
# running install
# running install_lib
# copying build/lib/tuner.py -> /tmp/tmpkiq0c0qv
# copying build/lib/trainer.py -> /tmp/tmpkiq0c0qv
# copying build/lib/transform.py -> /tmp/tmpkiq0c0qv
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmpkiq0c0qv/tfx_user_code_Trainer-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3.10.egg-info
# running install_scripts
# creating /tmp/tmpkiq0c0qv/tfx_user_code_Trainer-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/WHEEL
# creating '/tmp/tmpjux2ss66/tfx_user_code_Trainer-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3-none-any.whl' and adding '/tmp/tmpkiq0c0qv' to it
# adding 'trainer.py'
# adding 'transform.py'
# adding 'tuner.py'
# adding 'tfx_user_code_Trainer-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c.dist-info/RECORD'
# removing /tmp/tmpkiq0c0qv
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# Processing /workspaces/adult-census-income/main-pipeline/_wheels/tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Processing /workspaces/adult-census-income/main-pipeline/_wheels/tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Processing /workspaces/adult-census-income/main-pipeline/_wheels/tfx_user_code_Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_1/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_2/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_3/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_4/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_5/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_6/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_7/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_1/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_2/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_3/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_4/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_5/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_6/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_7/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# Processing /workspaces/adult-census-income/main-pipeline/_wheels/tfx_user_code_Tuner-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3-none-any.whl
# Installing collected packages: tfx-user-code-Tuner
# Successfully installed tfx-user-code-Tuner-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:tensorflow:From /workspaces/adult-census-income/venv/lib/python3.10/site-packages/tensorflow/python/data/experimental/ops/readers.py:1086: parse_example_dataset (from tensorflow.python.data.experimental.ops.parsing_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(tf.io.parse_example(...))` instead.
# WARNING:tensorflow:From /workspaces/adult-census-income/venv/lib/python3.10/site-packages/tensorflow/python/data/experimental/ops/readers.py:1086: parse_example_dataset (from tensorflow.python.data.experimental.ops.parsing_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(tf.io.parse_example(...))` instead.
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 128, 'step': 32, 'sampling': 'linear'}
# dropout_0 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.4, 'step': 0.1, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
#
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# 2                 |2                 |num_layers
# 32                |32                |units_0
# 0.2               |0.2               |dropout_0
# 0.001             |0.001             |learning_rate
#
# 20/20 [==============================] - 2s 21ms/step - loss: 0.9740 - accuracy: 0.4688 - val_loss: 0.8273 - val_accuracy: 0.5531
# Trial 1 Complete [00h 00m 02s]
# val_accuracy: 0.5531250238418579
#
# Best val_accuracy So Far: 0.5531250238418579
# Total elapsed time: 00h 00m 02s
#
# Search: Running Trial #2
#
# Value             |Best Value So Far |Hyperparameter
# 2                 |2                 |num_layers
# 64                |32                |units_0
# 0.3               |0.2               |dropout_0
# 0.01              |0.001             |learning_rate
# 128               |32                |units_1
# 0.4               |0.1               |dropout_1
#
# 20/20 [==============================] - 2s 29ms/step - loss: 0.6683 - accuracy: 0.7125 - val_loss: 0.4488 - val_accuracy: 0.7906
# Trial 2 Complete [00h 00m 02s]
# val_accuracy: 0.7906249761581421
#
# Best val_accuracy So Far: 0.7906249761581421
# Total elapsed time: 00h 00m 04s
#
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 2                 |2                 |num_layers
# 96                |64                |units_0
# 0.2               |0.3               |dropout_0
# 0.01              |0.01              |learning_rate
# 64                |128               |units_1
# 0.3               |0.4               |dropout_1
#
# 20/20 [==============================] - 2s 25ms/step - loss: 0.6381 - accuracy: 0.7031 - val_loss: 0.4386 - val_accuracy: 0.7875
# Trial 3 Complete [00h 00m 02s]
# val_accuracy: 0.7875000238418579
#
# Best val_accuracy So Far: 0.7906249761581421
# Total elapsed time: 00h 00m 06s
#
# Search: Running Trial #4
#
# Value             |Best Value So Far |Hyperparameter
# 2                 |2                 |num_layers
# 128               |64                |units_0
# 0.2               |0.3               |dropout_0
# 0.001             |0.01              |learning_rate
# 32                |128               |units_1
# 0.1               |0.4               |dropout_1
#
# 20/20 [==============================] - 1s 28ms/step - loss: 0.6958 - accuracy: 0.6469 - val_loss: 0.5806 - val_accuracy: 0.7781
# Trial 4 Complete [00h 00m 02s]
# val_accuracy: 0.778124988079071
#
# Best val_accuracy So Far: 0.7906249761581421
# Total elapsed time: 00h 00m 08s
#
# Search: Running Trial #5
#
# Value             |Best Value So Far |Hyperparameter
# 1                 |2                 |num_layers
# 128               |64                |units_0
# 0.1               |0.3               |dropout_0
# 0.0001            |0.01              |learning_rate
# 64                |128               |units_1
# 0.1               |0.4               |dropout_1
#
# 20/20 [==============================] - 1s 19ms/step - loss: 0.8376 - accuracy: 0.5047 - val_loss: 0.6560 - val_accuracy: 0.6500
# Trial 5 Complete [00h 00m 01s]
# val_accuracy: 0.6499999761581421
#
# Best val_accuracy So Far: 0.7906249761581421
# Total elapsed time: 00h 00m 09s
# Results summary
# Results in /workspaces/adult-census-income/main-pipeline/Tuner/.system/executor_execution/7/.temp/7/census_income_tuning
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 1 summary
# Hyperparameters:
# num_layers: 2
# units_0: 64
# dropout_0: 0.30000000000000004
# learning_rate: 0.01
# units_1: 128
# dropout_1: 0.4
# Score: 0.7906249761581421
#
# Trial 2 summary
# Hyperparameters:
# num_layers: 2
# units_0: 96
# dropout_0: 0.2
# learning_rate: 0.01
# units_1: 64
# dropout_1: 0.30000000000000004
# Score: 0.7875000238418579
#
# Trial 3 summary
# Hyperparameters:
# num_layers: 2
# units_0: 128
# dropout_0: 0.2
# learning_rate: 0.001
# units_1: 32
# dropout_1: 0.1
# Score: 0.778124988079071
#
# Trial 4 summary
# Hyperparameters:
# num_layers: 1
# units_0: 128
# dropout_0: 0.1
# learning_rate: 0.0001
# units_1: 64
# dropout_1: 0.1
# Score: 0.6499999761581421
#
# Trial 0 summary
# Hyperparameters:
# num_layers: 2
# units_0: 32
# dropout_0: 0.2
# learning_rate: 0.001
# units_1: 32
# dropout_1: 0.1
# Score: 0.5531250238418579
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# Processing /workspaces/adult-census-income/main-pipeline/_wheels/tfx_user_code_Trainer-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c-py3-none-any.whl
# Installing collected packages: tfx-user-code-Trainer
# Successfully installed tfx-user-code-Trainer-0.0+451393efe0c192707d9c623b53994fcf569deee8e2c65d8a1b6f6bfe952e443c
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Epoch 1/10
# 20/20 [==============================] - 2s 24ms/step - loss: 0.6255 - accuracy: 0.7312 - auc: 0.7623 - precision: 0.5355 - recall: 0.6043 - val_loss: 0.4039 - val_accuracy: 0.8219 - val_auc: 0.8220 - val_precision: 0.7000 - val_recall: 0.3043
# Epoch 2/10
# 20/20 [==============================] - 0s 11ms/step - loss: 0.4907 - accuracy: 0.7672 - auc: 0.8226 - precision: 0.6522 - recall: 0.5303 - val_loss: 0.4887 - val_accuracy: 0.7781 - val_auc: 0.7878 - val_precision: 1.0000 - val_recall: 0.0405
# Epoch 3/10
# 20/20 [==============================] - 0s 11ms/step - loss: 0.4660 - accuracy: 0.7859 - auc: 0.8221 - precision: 0.6545 - recall: 0.5745 - val_loss: 0.3900 - val_accuracy: 0.8281 - val_auc: 0.8388 - val_precision: 0.6977 - val_recall: 0.4167
# Epoch 4/10
# 20/20 [==============================] - 0s 11ms/step - loss: 0.4601 - accuracy: 0.8188 - auc: 0.8384 - precision: 0.7278 - recall: 0.6117 - val_loss: 0.4118 - val_accuracy: 0.8125 - val_auc: 0.8517 - val_precision: 0.8065 - val_recall: 0.3165
# Epoch 5/10
# 20/20 [==============================] - 0s 11ms/step - loss: 0.4052 - accuracy: 0.8109 - auc: 0.8682 - precision: 0.7244 - recall: 0.5916 - val_loss: 0.3867 - val_accuracy: 0.8250 - val_auc: 0.8619 - val_precision: 0.8214 - val_recall: 0.3108
# Epoch 6/10
# 20/20 [==============================] - 0s 10ms/step - loss: 0.4316 - accuracy: 0.7953 - auc: 0.8642 - precision: 0.6720 - recall: 0.6410 - val_loss: 0.4197 - val_accuracy: 0.7937 - val_auc: 0.8550 - val_precision: 0.7561 - val_recall: 0.3563
# Epoch 7/10
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4166 - accuracy: 0.8094 - auc: 0.8472 - precision: 0.6525 - recall: 0.5576 - val_loss: 0.4272 - val_accuracy: 0.7969 - val_auc: 0.8616 - val_precision: 0.8788 - val_recall: 0.3222
# Epoch 8/10
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4101 - accuracy: 0.7937 - auc: 0.8598 - precision: 0.6767 - recall: 0.5028 - val_loss: 0.3146 - val_accuracy: 0.8625 - val_auc: 0.9052 - val_precision: 0.7826 - val_recall: 0.5143
# Epoch 9/10
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3272 - accuracy: 0.8484 - auc: 0.9050 - precision: 0.7095 - recall: 0.6604 - val_loss: 0.4657 - val_accuracy: 0.8094 - val_auc: 0.8716 - val_precision: 0.8085 - val_recall: 0.4222
# Epoch 10/10
# 20/20 [==============================] - 0s 11ms/step - loss: 0.4018 - accuracy: 0.8109 - auc: 0.8632 - precision: 0.6899 - recall: 0.5235 - val_loss: 0.3537 - val_accuracy: 0.8313 - val_auc: 0.8695 - val_precision: 0.7500 - val_recall: 0.2727
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:tensorflow:From /workspaces/adult-census-income/venv/lib/python3.10/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:111: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /workspaces/adult-census-income/venv/lib/python3.10/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:111: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.

# %% [markdown]
# Pada sel di atas, skrip **`pipeline.py`** dieksekusi secara otomatis menggunakan **BeamDagRunner**. Komponen TFX yang dijalankan secara berurutan meliputi:
#
# - **ExampleGen:** Memuat dataset Adult Census Income dari file `data/adult.csv` dan membaginya menjadi dua rasio split (80% `train` dan 20% `eval`).
# - **StatisticsGen, SchemaGen, dan ExampleValidator:** Mengonsolidasi statistik deskriptif data, membuat skema tipe data, serta mengevaluasi potensi anomali pada dataset.
# - **Transform:** Menerapkan proses feature engineering berbasis modul `modules/transform.py` (standarisasi Z-score untuk fitur numerik dan vocabulary indexing untuk fitur kategorikal).
# - **Tuner:** Menjalankan pencarian hyperparameter optimal secara terotomatisasi via KerasTuner (`modules/tuner.py`).
# - **Trainer:** Melatih arsitektur Deep Neural Network menggunakan kombinasi hyperparameter terbaik (`modules/trainer.py`).
# - **Resolver:** Mengambil model blessed terakhir sebagai pembanding (baseline model).
# - **Evaluator:** Menilai performa model terhadap ambang batas akurasi minimal 60% dan memastikan nilainya lebih baik dibanding model baseline.
# - **Pusher:** Mengekspor file SavedModel yang siap deploy ke direktori `serving_model/adult-income-model` apabila model dinyatakan blessed.

# %% [markdown]
# ## **Memeriksa Folder Artifact**

# %%
pipeline_path = os.path.join("..", "main-pipeline")
print("Isi folder artifact pipeline:")
print(os.listdir(pipeline_path))
# Out:
# Isi folder artifact pipeline:
# ['Evaluator', 'Pusher', 'ExampleValidator', 'Tuner', 'Trainer', 'SchemaGen', 'StatisticsGen', '_wheels', 'metadata.sqlite', 'CsvExampleGen', 'Transform']

# %% [markdown]
# Setelah Apache Beam selesai menjalankan seluruh DAG, seluruh artifact pipeline tersimpan otomatis di direktori `main-pipeline/`.
